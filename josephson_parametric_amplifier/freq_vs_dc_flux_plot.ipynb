# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.genfromtxt(r'freq_vs_dc_flux.txt')
plt.plot(data[:,0],data[:,1],'.',markersize=8,color='black')
plt.plot([0.14,0.14],[5,6])
plt.ylim([5.2,5.9])
# Out:
# (5.2, 5.9)

# %%
5.6031*2
# Out:
# 11.2062

# %% [markdown]
# We used 140uA (the JPA doesn't work very well and we have to go to a region with a pretty large slope to get some amplification) and -5 dBm power. The frequency was 11.2062 GHz, so exactly double, we didn't tune it more).
